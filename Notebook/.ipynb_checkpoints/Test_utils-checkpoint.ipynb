# %%
import numpy as np
import pandas as pd
import pyomo.environ as pyo
import importlib.resources
import sys
import os
import json
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from utils import read_gmlc_gen

# %% [markdown]
# ## Read gen.csv

# %%
csv_path = os.path.join(os.getcwd(), '..', 'Data', 'gen.csv')
json_path = os.path.join(os.getcwd(), '..', 'Data', 'rtsgmle_gen_linear_cost_curve.json')
df = read_gmlc_gen(csv_path)
with open(json_path, 'rb') as f:
    gen_param_dict = json.load(f)
df
# Out:
#            GEN UID  Bus ID  Gen ID Unit Group Unit Type Category     Fuel  \
# 0         101_CT_1     101       1        U20        CT   Oil CT      Oil
# 1         101_CT_2     101       2        U20        CT   Oil CT      Oil
# 2      101_STEAM_3     101       3        U76     STEAM     Coal     Coal
# 3      101_STEAM_4     101       4        U76     STEAM     Coal     Coal
# 4         102_CT_1     102       1        U20        CT   Oil CT      Oil
# ..             ...     ...     ...        ...       ...      ...      ...
# 153     309_WIND_1     309       1       WIND      WIND     Wind     Wind
# 154     317_WIND_1     317       1       WIND      WIND     Wind     Wind
# 155     303_WIND_1     303       1       WIND      WIND     Wind     Wind
# 156     122_WIND_1     122       1       WIND      WIND     Wind     Wind
# 157  313_STORAGE_1     313       1    STORAGE   STORAGE  Storage  Storage
#
#      MW Inj  MVAR Inj  V Setpoint p.u.  ...  Emissions N2O Lbs/MMBTU  \
# 0       8.0      4.96           1.0468  ...                    0.004
# 1       8.0      4.96           1.0468  ...                    0.004
# 2      76.0      0.14           1.0468  ...                    0.004
# 3      76.0      0.14           1.0468  ...                    0.004
# 4       8.0      4.88           1.0467  ...                    0.004
# ..      ...       ...              ...  ...                      ...
# 153     0.0      0.00           1.0000  ...                    0.000
# 154     0.0      0.00           1.0000  ...                    0.000
# 155     0.0      0.00           1.0000  ...                    0.000
# 156     0.0      0.00           1.0000  ...                    0.000
# 157     0.0      0.00           1.0000  ...                    0.000
#
#      Emissions CO Lbs/MMBTU  Emissions VOCs Lbs/MMBTU  Damping Ratio  \
# 0                      0.11                     0.040              0
# 1                      0.11                     0.040              0
# 2                      0.02                     0.003              0
# 3                      0.02                     0.003              0
# 4                      0.11                     0.040              0
# ..                      ...                       ...            ...
# 153                    0.00                     0.000              0
# 154                    0.00                     0.000              0
# 155                    0.00                     0.000              0
# 156                    0.00                     0.000              0
# 157                    0.00                     0.000              0
#
#      Inertia MJ/MW  Base MVA  Transformer X p.u.  Unit X p.u.  Pump Load MW  \
# 0              2.8      24.0                0.13         0.32             0
# 1              2.8      24.0                0.13         0.32             0
# 2              3.0      89.0                0.13         0.30             0
# 3              3.0      89.0                0.13         0.30             0
# 4              2.8      24.0                0.13         0.32             0
# ..             ...       ...                 ...          ...           ...
# 153            0.0     148.3                0.00         0.00             0
# 154            0.0     799.1                0.00         0.00             0
# 155            0.0     847.0                0.00         0.00             0
# 156            0.0     713.5                0.00         0.00             0
# 157            0.0      50.0                0.00         0.00            50
#
#      Storage Roundtrip Efficiency
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ..                            ...
# 153                             0
# 154                             0
# 155                             0
# 156                             0
# 157                            85
#
# [158 rows x 57 columns]

# %%
# extract the CT, CC, STEAM, WIND, PV units
target_fossil_gen = []
target_renew_gen = []
for idx, row in df.iterrows():
    if row['Unit Type'] in ['CT', 'CC', 'STEAM']:
        target_fossil_gen.append(row)
    if row['Unit Type'] in ['PV', 'WIND']:
        target_renew_gen.append(row)
df_fossil = pd.DataFrame(target_fossil_gen)
df_renew = pd.DataFrame(target_renew_gen)

# %%
df_fossil
# Out:
#         GEN UID  Bus ID  Gen ID Unit Group Unit Type Category  Fuel  MW Inj  \
# 0      101_CT_1     101       1        U20        CT   Oil CT   Oil     8.0
# 1      101_CT_2     101       2        U20        CT   Oil CT   Oil     8.0
# 2   101_STEAM_3     101       3        U76     STEAM     Coal  Coal    76.0
# 3   101_STEAM_4     101       4        U76     STEAM     Coal  Coal    76.0
# 4      102_CT_1     102       1        U20        CT   Oil CT   Oil     8.0
# ..          ...     ...     ...        ...       ...      ...   ...     ...
# 67     321_CC_1     321       1       U355        CC   Gas CC    NG   355.0
# 68     322_CT_5     322       5        U55        CT   Gas CT    NG    55.0
# 69     322_CT_6     322       6        U55        CT   Gas CT    NG    55.0
# 70     323_CC_1     323       1       U355        CC   Gas CC    NG   355.0
# 71     323_CC_2     323       2       U355        CC   Gas CC    NG   355.0
#
#     MVAR Inj  V Setpoint p.u.  ...  Emissions N2O Lbs/MMBTU  \
# 0       4.96           1.0468  ...                    0.004
# 1       4.96           1.0468  ...                    0.004
# 2       0.14           1.0468  ...                    0.004
# 3       0.14           1.0468  ...                    0.004
# 4       4.88           1.0467  ...                    0.004
# ..       ...              ...  ...                      ...
# 67     -3.34           1.0500  ...                    0.000
# 68     -9.73           1.0500  ...                    0.000
# 69     -9.73           1.0500  ...                    0.000
# 70     37.41           1.0500  ...                    0.000
# 71     37.41           1.0500  ...                    0.000
#
#     Emissions CO Lbs/MMBTU  Emissions VOCs Lbs/MMBTU  Damping Ratio  \
# 0                     0.11                     0.040              0
# 1                     0.11                     0.040              0
# 2                     0.02                     0.003              0
# 3                     0.02                     0.003              0
# 4                     0.11                     0.040              0
# ..                     ...                       ...            ...
# 67                    0.00                     0.000              0
# 68                    0.00                     0.000              0
# 69                    0.00                     0.000              0
# 70                    0.00                     0.000              0
# 71                    0.00                     0.000              0
#
#     Inertia MJ/MW  Base MVA  Transformer X p.u.  Unit X p.u.  Pump Load MW  \
# 0             2.8      24.0                0.13         0.32             0
# 1             2.8      24.0                0.13         0.32             0
# 2             3.0      89.0                0.13         0.30             0
# 3             3.0      89.0                0.13         0.30             0
# 4             2.8      24.0                0.13         0.32             0
# ..            ...       ...                 ...          ...           ...
# 67            5.0     414.0                0.13         0.30             0
# 68            2.8      64.0                0.13         0.32             0
# 69            2.8      64.0                0.13         0.32             0
# 70            5.0     414.0                0.13         0.30             0
# 71            5.0     414.0                0.13         0.30             0
#
#     Storage Roundtrip Efficiency
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# ..                           ...
# 67                             0
# 68                             0
# 69                             0
# 70                             0
# 71                             0
#
# [72 rows x 57 columns]

# %% [markdown]
# ## calculate cost for the start up with different suitations

# %%
for idx, row in df_fossil.iterrows():
    fuel_price = row['Fuel Price $/MMBTU']
    cold_start_energy = row['Start Heat Cold MBTU']
    warm_start_energy = row['Start Heat Warm MBTU']
    hot_starat_energy = row['Start Heat Hot MBTU']
    
    cold_start_cost = fuel_price * cold_start_energy
    
for idx, row in df_fossil.iterrows():
    fuel_price = row['Fuel Price $/MMBTU']
    cold_start_energy = row['Start Heat Cold MBTU']
    warm_start_energy = row['Start Heat Warm MBTU']
    hot_starat_energy = row['Start Heat Hot MBTU']
    
    cold

# %%
fossil_dict = {}
for idx, row in df_fossil.iterrows():
    gen_name = row['GEN UID']
    gen_dict = {}
    gen_dict['name'] = gen_name
    gen_dict['gen_type'] = row['Unit Type']
    gen_dict['max_p'] = row['PMax MW']
    gen_dict['min_p'] = row['PMin MW']
    gen_dict['ramp_up'] = row['Ramp Rate MW/Min'] * 60 # ramp rate should be MW/hr
    gen_dict['min_down_time'] = np.round(row['Min Down Time Hr'], 0) # should be rounded to an integer
    gen_dict['min_up_time'] = np.round(row['Min Up Time Hr'], 0) # should be rounded to an integer
    gen_dict['start_up_time_hot'] = row['Start Time Hot Hr']
    gen_dict['start_up_time_warm'] = row['Start Time Warm Hr']
    gen_dict['start_up_time_cold'] = row['Start Time Cold Hr']
    gen_dict['cost_curve'] = gen_param_dict[gen_name]
    
    fossil_dict[gen_name] = gen_dict

# %%
renew_dict = {}
for idx, row in df_renew.iterrows():
    gen_name = row['GEN UID']
    gen_dict = {}
    gen_dict['name'] = gen_name
    gen_dict['gen_type'] = row['Unit Type']
    gen_dict['max_p'] = row['PMax MW']
    gen_dict['min_p'] = row['PMin MW']
    gen_dict['ramp_up'] = row['Ramp Rate MW/Min']
    gen_dict['min_down_time'] = row['Min Down Time Hr']
    gen_dict['min_up_time'] = row['Min Up Time Hr']
    gen_dict['start_up_time_hot'] = row['Start Time Hot Hr']
    gen_dict['start_up_time_cold'] = row['Start Time Cold Hr']
    gen_dict['start_up_time_cold'] = row['Start Time Warm Hr']
    gen_dict['cost_curve'] = {'slope': 0, 'intercept': 0} # for the renewable generators, the operation cost is 0.
    
    renew_dict[gen_name] = gen_dict

# %%
all_gen_dict = {}
all_gen_dict['fossil'] = fossil_dict
all_gen_dict['renew'] = renew_dict

gen_dict_path = os.path.join(os.getcwd(), '..', 'Data', 'gen_dict.json')

with open(gen_dict_path, "w") as f:
    json.dump(all_gen_dict, f)

print("Successfully saved generator parameters to json files")
# Out:
# Successfully saved generator parameters to json files
